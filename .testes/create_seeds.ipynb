# %%
import json
import chardet

# %%
with open('jogos.json', 'rb') as f=
    result = chardet.detect(f.read())

# Abra o arquivo json com a codificação detectada
with open('jogos.json', 'r', encoding=result['encoding']) as f=
    dados = json.load(f)

# %%
for item in dados:
    for matche in item['matches']:
        print(f'new FutebolVirtualGames')
        print('{')
        print(f'    Id = {matche['Id']},')
        print(f'    LeagueId = {item['Id']},')
        print(f'    League = "{item['competition']}",')
        print(f'    HomeTeam = "{matche['TeamHome']}",')
        print(f'    AwayTeam = "{matche['TeamAway']}",')
        print(f'    SumScore = {matche['SumScore']},')
        print(f'    FinalTimeResult = "{matche['FinalTimeResult']}",')
        print(f'    HalfTimeResult = "{matche['HalfTimeResult']}",')
        print(f'    GameDate = DateTime.Parse("{matche['Date']}"),')
        print(f'    HomeImg = "{matche['HomeImg']}",')
        print(f'    AwayImg = "{matche['AwayImg']}"')
        print('},')
# Out:
# new FutebolVirtualGames
# {
#     Id = 2998050,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Irã",
#     AwayTeam = "Portugal",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T23:58:00"),
#     HomeImg = "1.png",
#     AwayImg = "28.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2998047,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Alemanha",
#     AwayTeam = "Marrocos",
#     SumScore = 4,
#     FinalTimeResult = "1-3",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T23:55:00"),
#     HomeImg = "9.png",
#     AwayImg = "Marrocos.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2998043,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Bélgica",
#     AwayTeam = "Sérvia",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T23:52:00"),
#     HomeImg = "32.png",
#     AwayImg = "eu_7.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2998039,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Japão",
#     AwayTeam = "Gana",
#     SumScore = 5,
#     FinalTimeResult = "2-3",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T23:49:00"),
#     HomeImg = "16.png",
#     AwayImg = "11.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2998034,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "País de Gales",
#     AwayTeam = "Equador",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T23:46:00"),
#     HomeImg = "eu_24.png",
#     AwayImg = "13.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2998030,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Canadá",
#     AwayTeam = "Costa Rica",
#     SumScore = 2,
#     FinalTimeResult = "2-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T23:43:00"),
#     HomeImg = "Canadá.png",
#     AwayImg = "22.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2998024,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Dinamarca",
#     AwayTeam = "Tunísia",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T23:40:00"),
#     HomeImg = "eu_23.png",
#     AwayImg = "Tunísia.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2998021,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Canadá",
#     AwayTeam = "Brasil",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T23:37:00"),
#     HomeImg = "Canadá.png",
#     AwayImg = "19.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2998017,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Croácia",
#     AwayTeam = "Alemanha",
#     SumScore = 3,
#     FinalTimeResult = "0-3",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T23:34:00"),
#     HomeImg = "18.png",
#     AwayImg = "9.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2998012,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "País de Gales",
#     AwayTeam = "Brasil",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T23:31:00"),
#     HomeImg = "eu_24.png",
#     AwayImg = "19.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2998007,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Coréia Do Sul",
#     AwayTeam = "Marrocos",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T23:28:00"),
#     HomeImg = "26.png",
#     AwayImg = "Marrocos.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2998004,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Sérvia",
#     AwayTeam = "Inglaterra",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T23:25:00"),
#     HomeImg = "eu_7.png",
#     AwayImg = "14.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2998000,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Argentina",
#     AwayTeam = "Bélgica",
#     SumScore = 3,
#     FinalTimeResult = "2-1",
#     HalfTimeResult = "1-1",
#     GameDate = DateTime.Parse("2023-12-27T23:22:00"),
#     HomeImg = "8.png",
#     AwayImg = "32.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997995,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "França",
#     AwayTeam = "Austrália",
#     SumScore = 2,
#     FinalTimeResult = "2-0",
#     HalfTimeResult = "2-0",
#     GameDate = DateTime.Parse("2023-12-27T23:19:00"),
#     HomeImg = "31.png",
#     AwayImg = "25.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997988,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Gana",
#     AwayTeam = "Bélgica",
#     SumScore = 4,
#     FinalTimeResult = "2-2",
#     HalfTimeResult = "1-1",
#     GameDate = DateTime.Parse("2023-12-27T23:16:00"),
#     HomeImg = "11.png",
#     AwayImg = "32.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997985,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Uruguai",
#     AwayTeam = "Canadá",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T23:13:00"),
#     HomeImg = "23.png",
#     AwayImg = "Canadá.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997979,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Irã",
#     AwayTeam = "Sérvia",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "1-1",
#     GameDate = DateTime.Parse("2023-12-27T23:10:00"),
#     HomeImg = "1.png",
#     AwayImg = "eu_7.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997974,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Camarões",
#     AwayTeam = "França",
#     SumScore = 3,
#     FinalTimeResult = "1-2",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T23:07:00"),
#     HomeImg = "6.png",
#     AwayImg = "31.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997970,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Argentina",
#     AwayTeam = "México",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T23:04:00"),
#     HomeImg = "8.png",
#     AwayImg = "20.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997967,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Arábia Saudita",
#     AwayTeam = "Tunísia",
#     SumScore = 4,
#     FinalTimeResult = "2-2",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T23:01:00"),
#     HomeImg = "Arábia Saudita.png",
#     AwayImg = "Tunísia.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997962,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Alemanha",
#     AwayTeam = "Portugal",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T22:58:00"),
#     HomeImg = "9.png",
#     AwayImg = "28.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997956,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Suíça",
#     AwayTeam = "Argentina",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T22:55:00"),
#     HomeImg = "12.png",
#     AwayImg = "8.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997952,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Bélgica",
#     AwayTeam = "Brasil",
#     SumScore = 5,
#     FinalTimeResult = "4-1",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T22:52:00"),
#     HomeImg = "32.png",
#     AwayImg = "19.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997949,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Gana",
#     AwayTeam = "Portugal",
#     SumScore = 3,
#     FinalTimeResult = "1-2",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T22:49:00"),
#     HomeImg = "11.png",
#     AwayImg = "28.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997945,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Croácia",
#     AwayTeam = "México",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T22:46:00"),
#     HomeImg = "18.png",
#     AwayImg = "20.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997939,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Qatar",
#     AwayTeam = "Irã",
#     SumScore = 3,
#     FinalTimeResult = "2-1",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T22:43:00"),
#     HomeImg = "Qatar.jpg",
#     AwayImg = "1.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997936,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Alemanha",
#     AwayTeam = "Países Baixos",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T22:40:00"),
#     HomeImg = "9.png",
#     AwayImg = "eu_37.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997929,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Qatar",
#     AwayTeam = "Sérvia",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T22:37:00"),
#     HomeImg = "Qatar.jpg",
#     AwayImg = "eu_7.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997926,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "País de Gales",
#     AwayTeam = "Argentina",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T22:34:00"),
#     HomeImg = "eu_24.png",
#     AwayImg = "8.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997922,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Alemanha",
#     AwayTeam = "Eua",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T22:31:00"),
#     HomeImg = "9.png",
#     AwayImg = "21.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997916,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Costa Rica",
#     AwayTeam = "Qatar",
#     SumScore = 3,
#     FinalTimeResult = "0-3",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T22:28:00"),
#     HomeImg = "22.png",
#     AwayImg = "Qatar.jpg"
# },
# new FutebolVirtualGames
# {
#     Id = 2997912,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Brasil",
#     AwayTeam = "Inglaterra",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T22:25:00"),
#     HomeImg = "19.png",
#     AwayImg = "14.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997908,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Uruguai",
#     AwayTeam = "Arábia Saudita",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T22:22:00"),
#     HomeImg = "23.png",
#     AwayImg = "Arábia Saudita.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997905,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Espanha",
#     AwayTeam = "Marrocos",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T22:19:00"),
#     HomeImg = "4.png",
#     AwayImg = "Marrocos.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997900,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Portugal",
#     AwayTeam = "México",
#     SumScore = 2,
#     FinalTimeResult = "2-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T22:16:00"),
#     HomeImg = "28.png",
#     AwayImg = "20.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997895,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "França",
#     AwayTeam = "Qatar",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T22:13:00"),
#     HomeImg = "31.png",
#     AwayImg = "Qatar.jpg"
# },
# new FutebolVirtualGames
# {
#     Id = 2997891,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Canadá",
#     AwayTeam = "Espanha",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T22:10:00"),
#     HomeImg = "Canadá.png",
#     AwayImg = "4.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997886,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Japão",
#     AwayTeam = "Qatar",
#     SumScore = 4,
#     FinalTimeResult = "3-1",
#     HalfTimeResult = "2-0",
#     GameDate = DateTime.Parse("2023-12-27T22:07:00"),
#     HomeImg = "16.png",
#     AwayImg = "Qatar.jpg"
# },
# new FutebolVirtualGames
# {
#     Id = 2997882,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Inglaterra",
#     AwayTeam = "Costa Rica",
#     SumScore = 4,
#     FinalTimeResult = "4-0",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T22:04:00"),
#     HomeImg = "14.png",
#     AwayImg = "22.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997878,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "França",
#     AwayTeam = "Sérvia",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "1-1",
#     GameDate = DateTime.Parse("2023-12-27T22:01:00"),
#     HomeImg = "31.png",
#     AwayImg = "eu_7.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997874,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Portugal",
#     AwayTeam = "Inglaterra",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T21:58:00"),
#     HomeImg = "28.png",
#     AwayImg = "14.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997869,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Sérvia",
#     AwayTeam = "Coréia Do Sul",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T21:55:00"),
#     HomeImg = "eu_7.png",
#     AwayImg = "26.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997865,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Austrália",
#     AwayTeam = "Qatar",
#     SumScore = 3,
#     FinalTimeResult = "2-1",
#     HalfTimeResult = "2-0",
#     GameDate = DateTime.Parse("2023-12-27T21:52:00"),
#     HomeImg = "25.png",
#     AwayImg = "Qatar.jpg"
# },
# new FutebolVirtualGames
# {
#     Id = 2997862,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Portugal",
#     AwayTeam = "Costa Rica",
#     SumScore = 4,
#     FinalTimeResult = "2-2",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T21:49:00"),
#     HomeImg = "28.png",
#     AwayImg = "22.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997857,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Bélgica",
#     AwayTeam = "Suíça",
#     SumScore = 3,
#     FinalTimeResult = "2-1",
#     HalfTimeResult = "1-1",
#     GameDate = DateTime.Parse("2023-12-27T21:46:00"),
#     HomeImg = "32.png",
#     AwayImg = "12.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997853,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Equador",
#     AwayTeam = "Marrocos",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T21:43:00"),
#     HomeImg = "13.png",
#     AwayImg = "Marrocos.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997849,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Brasil",
#     AwayTeam = "Irã",
#     SumScore = 3,
#     FinalTimeResult = "1-2",
#     HalfTimeResult = "0-2",
#     GameDate = DateTime.Parse("2023-12-27T21:40:00"),
#     HomeImg = "19.png",
#     AwayImg = "1.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997844,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Arábia Saudita",
#     AwayTeam = "Croácia",
#     SumScore = 3,
#     FinalTimeResult = "2-1",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T21:37:00"),
#     HomeImg = "Arábia Saudita.png",
#     AwayImg = "18.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997840,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Alemanha",
#     AwayTeam = "Canadá",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T21:34:00"),
#     HomeImg = "9.png",
#     AwayImg = "Canadá.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997835,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Brasil",
#     AwayTeam = "Costa Rica",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T21:31:00"),
#     HomeImg = "19.png",
#     AwayImg = "22.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997831,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Irã",
#     AwayTeam = "Uruguai",
#     SumScore = 4,
#     FinalTimeResult = "2-2",
#     HalfTimeResult = "2-0",
#     GameDate = DateTime.Parse("2023-12-27T21:28:00"),
#     HomeImg = "1.png",
#     AwayImg = "23.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997828,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Países Baixos",
#     AwayTeam = "Argentina",
#     SumScore = 2,
#     FinalTimeResult = "2-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T21:25:00"),
#     HomeImg = "eu_37.png",
#     AwayImg = "8.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997822,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Dinamarca",
#     AwayTeam = "Qatar",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T21:22:00"),
#     HomeImg = "eu_23.png",
#     AwayImg = "Qatar.jpg"
# },
# new FutebolVirtualGames
# {
#     Id = 2997818,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Países Baixos",
#     AwayTeam = "Alemanha",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T21:19:00"),
#     HomeImg = "eu_37.png",
#     AwayImg = "9.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997813,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Dinamarca",
#     AwayTeam = "Gana",
#     SumScore = 4,
#     FinalTimeResult = "4-0",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T21:16:00"),
#     HomeImg = "eu_23.png",
#     AwayImg = "11.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997809,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Arábia Saudita",
#     AwayTeam = "Costa Rica",
#     SumScore = 5,
#     FinalTimeResult = "4-1",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T21:13:00"),
#     HomeImg = "Arábia Saudita.png",
#     AwayImg = "22.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997804,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Argentina",
#     AwayTeam = "Equador",
#     SumScore = 2,
#     FinalTimeResult = "2-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T21:10:00"),
#     HomeImg = "8.png",
#     AwayImg = "13.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997800,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Suíça",
#     AwayTeam = "Croácia",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T21:07:00"),
#     HomeImg = "12.png",
#     AwayImg = "18.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997795,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Dinamarca",
#     AwayTeam = "País de Gales",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T21:04:00"),
#     HomeImg = "eu_23.png",
#     AwayImg = "eu_24.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997792,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Irã",
#     AwayTeam = "Tunísia",
#     SumScore = 2,
#     FinalTimeResult = "2-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T21:01:00"),
#     HomeImg = "1.png",
#     AwayImg = "Tunísia.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997787,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Equador",
#     AwayTeam = "Uruguai",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T20:58:00"),
#     HomeImg = "13.png",
#     AwayImg = "23.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997784,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Inglaterra",
#     AwayTeam = "Portugal",
#     SumScore = 2,
#     FinalTimeResult = "2-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T20:55:00"),
#     HomeImg = "14.png",
#     AwayImg = "28.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997779,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Dinamarca",
#     AwayTeam = "Costa Rica",
#     SumScore = 4,
#     FinalTimeResult = "3-1",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T20:52:00"),
#     HomeImg = "eu_23.png",
#     AwayImg = "22.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997776,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Marrocos",
#     AwayTeam = "México",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T20:49:00"),
#     HomeImg = "Marrocos.png",
#     AwayImg = "20.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997770,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Gana",
#     AwayTeam = "Suíça",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T20:46:00"),
#     HomeImg = "11.png",
#     AwayImg = "12.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997766,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Bélgica",
#     AwayTeam = "Portugal",
#     SumScore = 6,
#     FinalTimeResult = "3-3",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T20:43:00"),
#     HomeImg = "32.png",
#     AwayImg = "28.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997762,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "México",
#     AwayTeam = "Eua",
#     SumScore = 4,
#     FinalTimeResult = "1-3",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T20:40:00"),
#     HomeImg = "20.png",
#     AwayImg = "21.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997758,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Austrália",
#     AwayTeam = "Bélgica",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T20:37:00"),
#     HomeImg = "25.png",
#     AwayImg = "32.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997752,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Suíça",
#     AwayTeam = "Eua",
#     SumScore = 3,
#     FinalTimeResult = "1-2",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T20:34:00"),
#     HomeImg = "12.png",
#     AwayImg = "21.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997747,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "França",
#     AwayTeam = "Espanha",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T20:31:00"),
#     HomeImg = "31.png",
#     AwayImg = "4.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997743,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Alemanha",
#     AwayTeam = "Austrália",
#     SumScore = 2,
#     FinalTimeResult = "2-0",
#     HalfTimeResult = "2-0",
#     GameDate = DateTime.Parse("2023-12-27T20:28:00"),
#     HomeImg = "9.png",
#     AwayImg = "25.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997739,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Polônia",
#     AwayTeam = "México",
#     SumScore = 3,
#     FinalTimeResult = "2-1",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T20:25:00"),
#     HomeImg = "eu_3.png",
#     AwayImg = "20.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997735,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Costa Rica",
#     AwayTeam = "Suíça",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T20:22:00"),
#     HomeImg = "22.png",
#     AwayImg = "12.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997731,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Arábia Saudita",
#     AwayTeam = "Coréia Do Sul",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T20:19:00"),
#     HomeImg = "Arábia Saudita.png",
#     AwayImg = "26.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997727,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Bélgica",
#     AwayTeam = "Equador",
#     SumScore = 3,
#     FinalTimeResult = "3-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T20:16:00"),
#     HomeImg = "32.png",
#     AwayImg = "13.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997722,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Irã",
#     AwayTeam = "Costa Rica",
#     SumScore = 3,
#     FinalTimeResult = "2-1",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T20:13:00"),
#     HomeImg = "1.png",
#     AwayImg = "22.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997719,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "País de Gales",
#     AwayTeam = "Polônia",
#     SumScore = 4,
#     FinalTimeResult = "2-2",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T20:10:00"),
#     HomeImg = "eu_24.png",
#     AwayImg = "eu_3.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997714,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Inglaterra",
#     AwayTeam = "Tunísia",
#     SumScore = 3,
#     FinalTimeResult = "1-2",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T20:07:00"),
#     HomeImg = "14.png",
#     AwayImg = "Tunísia.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997710,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "México",
#     AwayTeam = "Sérvia",
#     SumScore = 3,
#     FinalTimeResult = "1-2",
#     HalfTimeResult = "0-2",
#     GameDate = DateTime.Parse("2023-12-27T20:04:00"),
#     HomeImg = "20.png",
#     AwayImg = "eu_7.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997705,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Croácia",
#     AwayTeam = "Dinamarca",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T20:01:00"),
#     HomeImg = "18.png",
#     AwayImg = "eu_23.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997700,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Brasil",
#     AwayTeam = "França",
#     SumScore = 2,
#     FinalTimeResult = "0-2",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T19:58:00"),
#     HomeImg = "19.png",
#     AwayImg = "31.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997697,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Sérvia",
#     AwayTeam = "Alemanha",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T19:55:00"),
#     HomeImg = "eu_7.png",
#     AwayImg = "9.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997691,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Qatar",
#     AwayTeam = "França",
#     SumScore = 4,
#     FinalTimeResult = "1-3",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T19:52:00"),
#     HomeImg = "Qatar.jpg",
#     AwayImg = "31.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997686,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Canadá",
#     AwayTeam = "Marrocos",
#     SumScore = 4,
#     FinalTimeResult = "1-3",
#     HalfTimeResult = "1-1",
#     GameDate = DateTime.Parse("2023-12-27T19:49:00"),
#     HomeImg = "Canadá.png",
#     AwayImg = "Marrocos.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997683,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Eua",
#     AwayTeam = "Equador",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T19:46:00"),
#     HomeImg = "21.png",
#     AwayImg = "13.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997678,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Japão",
#     AwayTeam = "Arábia Saudita",
#     SumScore = 3,
#     FinalTimeResult = "3-0",
#     HalfTimeResult = "2-0",
#     GameDate = DateTime.Parse("2023-12-27T19:43:00"),
#     HomeImg = "16.png",
#     AwayImg = "Arábia Saudita.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997673,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Camarões",
#     AwayTeam = "Países Baixos",
#     SumScore = 4,
#     FinalTimeResult = "3-1",
#     HalfTimeResult = "2-0",
#     GameDate = DateTime.Parse("2023-12-27T19:40:00"),
#     HomeImg = "6.png",
#     AwayImg = "eu_37.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997670,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Eua",
#     AwayTeam = "Alemanha",
#     SumScore = 2,
#     FinalTimeResult = "2-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T19:37:00"),
#     HomeImg = "21.png",
#     AwayImg = "9.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997665,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Canadá",
#     AwayTeam = "Senegal",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T19:34:00"),
#     HomeImg = "Canadá.png",
#     AwayImg = "Senegal.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997661,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Croácia",
#     AwayTeam = "Suíça",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T19:31:00"),
#     HomeImg = "18.png",
#     AwayImg = "12.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997658,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Austrália",
#     AwayTeam = "Camarões",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T19:28:00"),
#     HomeImg = "25.png",
#     AwayImg = "6.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997653,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Marrocos",
#     AwayTeam = "Tunísia",
#     SumScore = 5,
#     FinalTimeResult = "5+-0",
#     HalfTimeResult = "2-0",
#     GameDate = DateTime.Parse("2023-12-27T19:25:00"),
#     HomeImg = "Marrocos.png",
#     AwayImg = "Tunísia.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997648,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Croácia",
#     AwayTeam = "Arábia Saudita",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T19:22:00"),
#     HomeImg = "18.png",
#     AwayImg = "Arábia Saudita.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997645,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Austrália",
#     AwayTeam = "Eua",
#     SumScore = 4,
#     FinalTimeResult = "2-2",
#     HalfTimeResult = "0-2",
#     GameDate = DateTime.Parse("2023-12-27T19:19:00"),
#     HomeImg = "25.png",
#     AwayImg = "21.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997640,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "França",
#     AwayTeam = "País de Gales",
#     SumScore = 4,
#     FinalTimeResult = "2-2",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T19:16:00"),
#     HomeImg = "31.png",
#     AwayImg = "eu_24.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997634,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Uruguai",
#     AwayTeam = "Portugal",
#     SumScore = 3,
#     FinalTimeResult = "2-1",
#     HalfTimeResult = "1-1",
#     GameDate = DateTime.Parse("2023-12-27T19:13:00"),
#     HomeImg = "23.png",
#     AwayImg = "28.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997629,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Senegal",
#     AwayTeam = "Sérvia",
#     SumScore = 3,
#     FinalTimeResult = "3-0",
#     HalfTimeResult = "2-0",
#     GameDate = DateTime.Parse("2023-12-27T19:10:00"),
#     HomeImg = "Senegal.png",
#     AwayImg = "eu_7.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997626,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Uruguai",
#     AwayTeam = "Tunísia",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T19:07:00"),
#     HomeImg = "23.png",
#     AwayImg = "Tunísia.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997620,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Canadá",
#     AwayTeam = "Coréia Do Sul",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T19:04:00"),
#     HomeImg = "Canadá.png",
#     AwayImg = "26.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997616,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Irã",
#     AwayTeam = "Inglaterra",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T19:01:00"),
#     HomeImg = "1.png",
#     AwayImg = "14.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997611,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Brasil",
#     AwayTeam = "Eua",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T18:58:00"),
#     HomeImg = "19.png",
#     AwayImg = "21.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997606,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Inglaterra",
#     AwayTeam = "Camarões",
#     SumScore = 2,
#     FinalTimeResult = "2-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T18:55:00"),
#     HomeImg = "14.png",
#     AwayImg = "6.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997601,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "México",
#     AwayTeam = "País de Gales",
#     SumScore = 2,
#     FinalTimeResult = "2-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T18:52:00"),
#     HomeImg = "20.png",
#     AwayImg = "eu_24.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997597,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Portugal",
#     AwayTeam = "Senegal",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T18:49:00"),
#     HomeImg = "28.png",
#     AwayImg = "Senegal.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997590,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Polônia",
#     AwayTeam = "Gana",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T18:46:00"),
#     HomeImg = "eu_3.png",
#     AwayImg = "11.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997585,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Senegal",
#     AwayTeam = "Coréia Do Sul",
#     SumScore = 4,
#     FinalTimeResult = "3-1",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T18:43:00"),
#     HomeImg = "Senegal.png",
#     AwayImg = "26.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997582,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Países Baixos",
#     AwayTeam = "Arábia Saudita",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T18:40:00"),
#     HomeImg = "eu_37.png",
#     AwayImg = "Arábia Saudita.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997577,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Sérvia",
#     AwayTeam = "Tunísia",
#     SumScore = 2,
#     FinalTimeResult = "2-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T18:37:00"),
#     HomeImg = "eu_7.png",
#     AwayImg = "Tunísia.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997574,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Argentina",
#     AwayTeam = "Eua",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T18:34:00"),
#     HomeImg = "8.png",
#     AwayImg = "21.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997569,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "México",
#     AwayTeam = "Austrália",
#     SumScore = 4,
#     FinalTimeResult = "2-2",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T18:31:00"),
#     HomeImg = "20.png",
#     AwayImg = "25.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997566,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Croácia",
#     AwayTeam = "Equador",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T18:28:00"),
#     HomeImg = "18.png",
#     AwayImg = "13.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997562,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Senegal",
#     AwayTeam = "Bélgica",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T18:25:00"),
#     HomeImg = "Senegal.png",
#     AwayImg = "32.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997558,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Arábia Saudita",
#     AwayTeam = "Portugal",
#     SumScore = 2,
#     FinalTimeResult = "2-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T18:22:00"),
#     HomeImg = "Arábia Saudita.png",
#     AwayImg = "28.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997554,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Senegal",
#     AwayTeam = "Tunísia",
#     SumScore = 2,
#     FinalTimeResult = "0-2",
#     HalfTimeResult = "0-2",
#     GameDate = DateTime.Parse("2023-12-27T18:19:00"),
#     HomeImg = "Senegal.png",
#     AwayImg = "Tunísia.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997549,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Coréia Do Sul",
#     AwayTeam = "Espanha",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T18:16:00"),
#     HomeImg = "26.png",
#     AwayImg = "4.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997543,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Alemanha",
#     AwayTeam = "Irã",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "1-1",
#     GameDate = DateTime.Parse("2023-12-27T18:13:00"),
#     HomeImg = "9.png",
#     AwayImg = "1.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997540,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Brasil",
#     AwayTeam = "Espanha",
#     SumScore = 3,
#     FinalTimeResult = "2-1",
#     HalfTimeResult = "2-0",
#     GameDate = DateTime.Parse("2023-12-27T18:10:00"),
#     HomeImg = "19.png",
#     AwayImg = "4.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997534,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Alemanha",
#     AwayTeam = "Tunísia",
#     SumScore = 2,
#     FinalTimeResult = "2-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T18:07:00"),
#     HomeImg = "9.png",
#     AwayImg = "Tunísia.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997529,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Dinamarca",
#     AwayTeam = "Brasil",
#     SumScore = 3,
#     FinalTimeResult = "2-1",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T18:04:00"),
#     HomeImg = "eu_23.png",
#     AwayImg = "19.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997522,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Bélgica",
#     AwayTeam = "Austrália",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T18:01:00"),
#     HomeImg = "32.png",
#     AwayImg = "25.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997518,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Argentina",
#     AwayTeam = "Uruguai",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T17:58:00"),
#     HomeImg = "8.png",
#     AwayImg = "23.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997513,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Inglaterra",
#     AwayTeam = "Bélgica",
#     SumScore = 3,
#     FinalTimeResult = "3-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T17:55:00"),
#     HomeImg = "14.png",
#     AwayImg = "32.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997508,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Marrocos",
#     AwayTeam = "Arábia Saudita",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T17:52:00"),
#     HomeImg = "Marrocos.png",
#     AwayImg = "Arábia Saudita.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997504,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Portugal",
#     AwayTeam = "França",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T17:49:00"),
#     HomeImg = "28.png",
#     AwayImg = "31.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997499,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Alemanha",
#     AwayTeam = "Uruguai",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T17:46:00"),
#     HomeImg = "9.png",
#     AwayImg = "23.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997495,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Qatar",
#     AwayTeam = "Camarões",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T17:43:00"),
#     HomeImg = "Qatar.jpg",
#     AwayImg = "6.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997491,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Arábia Saudita",
#     AwayTeam = "Alemanha",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T17:40:00"),
#     HomeImg = "Arábia Saudita.png",
#     AwayImg = "9.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997486,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Países Baixos",
#     AwayTeam = "Camarões",
#     SumScore = 5,
#     FinalTimeResult = "1-4",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T17:37:00"),
#     HomeImg = "eu_37.png",
#     AwayImg = "6.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997482,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Eua",
#     AwayTeam = "Tunísia",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T17:34:00"),
#     HomeImg = "21.png",
#     AwayImg = "Tunísia.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997477,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Brasil",
#     AwayTeam = "Suíça",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T17:31:00"),
#     HomeImg = "19.png",
#     AwayImg = "12.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997474,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Sérvia",
#     AwayTeam = "Costa Rica",
#     SumScore = 3,
#     FinalTimeResult = "1-2",
#     HalfTimeResult = "0-2",
#     GameDate = DateTime.Parse("2023-12-27T17:28:00"),
#     HomeImg = "eu_7.png",
#     AwayImg = "22.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997469,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Austrália",
#     AwayTeam = "Gana",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T17:25:00"),
#     HomeImg = "25.png",
#     AwayImg = "11.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997464,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Argentina",
#     AwayTeam = "Alemanha",
#     SumScore = 3,
#     FinalTimeResult = "2-1",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T17:22:00"),
#     HomeImg = "8.png",
#     AwayImg = "9.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997461,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Suíça",
#     AwayTeam = "Dinamarca",
#     SumScore = 3,
#     FinalTimeResult = "2-1",
#     HalfTimeResult = "1-1",
#     GameDate = DateTime.Parse("2023-12-27T17:19:00"),
#     HomeImg = "12.png",
#     AwayImg = "eu_23.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997455,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Tunísia",
#     AwayTeam = "Senegal",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T17:16:00"),
#     HomeImg = "Tunísia.png",
#     AwayImg = "Senegal.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997451,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Espanha",
#     AwayTeam = "França",
#     SumScore = 4,
#     FinalTimeResult = "1-3",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T17:13:00"),
#     HomeImg = "4.png",
#     AwayImg = "31.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997448,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Costa Rica",
#     AwayTeam = "Polônia",
#     SumScore = 4,
#     FinalTimeResult = "1-3",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T17:10:00"),
#     HomeImg = "22.png",
#     AwayImg = "eu_3.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997443,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Uruguai",
#     AwayTeam = "Coréia Do Sul",
#     SumScore = 5,
#     FinalTimeResult = "4-1",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T17:07:00"),
#     HomeImg = "23.png",
#     AwayImg = "26.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997440,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Argentina",
#     AwayTeam = "Canadá",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T17:04:00"),
#     HomeImg = "8.png",
#     AwayImg = "Canadá.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997436,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Espanha",
#     AwayTeam = "Gana",
#     SumScore = 4,
#     FinalTimeResult = "1-3",
#     HalfTimeResult = "0-2",
#     GameDate = DateTime.Parse("2023-12-27T17:01:00"),
#     HomeImg = "4.png",
#     AwayImg = "11.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997431,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Uruguai",
#     AwayTeam = "Marrocos",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T16:58:00"),
#     HomeImg = "23.png",
#     AwayImg = "Marrocos.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997426,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Alemanha",
#     AwayTeam = "Qatar",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T16:55:00"),
#     HomeImg = "9.png",
#     AwayImg = "Qatar.jpg"
# },
# new FutebolVirtualGames
# {
#     Id = 2997422,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Japão",
#     AwayTeam = "Marrocos",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T16:52:00"),
#     HomeImg = "16.png",
#     AwayImg = "Marrocos.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2997418,
#     LeagueId = 20120650,
#     League = "Copa do Mundo",
#     HomeTeam = "Suíça",
#     AwayTeam = "Senegal",
#     SumScore = 4,
#     FinalTimeResult = "2-2",
# ...
#     HomeTeam = "Newcastle",
#     AwayTeam = "Palace",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T02:18:00"),
#     HomeImg = "Newcastle.png",
#     AwayImg = "Palace.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996182,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Leicester",
#     AwayTeam = "United",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T02:15:00"),
#     HomeImg = "Leicester.png",
#     AwayImg = "United.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996177,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Liverpool",
#     AwayTeam = "Everton",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T02:12:00"),
#     HomeImg = "Liverpool.png",
#     AwayImg = "Everton.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996173,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Norwich",
#     AwayTeam = "Newcastle",
#     SumScore = 3,
#     FinalTimeResult = "2-1",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T02:09:00"),
#     HomeImg = "Norwich.png",
#     AwayImg = "Newcastle.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996168,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "City",
#     AwayTeam = "Brighton",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "1-1",
#     GameDate = DateTime.Parse("2023-12-27T02:06:00"),
#     HomeImg = "City.png",
#     AwayImg = "Brighton.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996163,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Leicester",
#     AwayTeam = "Newcastle",
#     SumScore = 6,
#     FinalTimeResult = "4-2",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T02:03:00"),
#     HomeImg = "Leicester.png",
#     AwayImg = "Newcastle.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996158,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Chelsea",
#     AwayTeam = "Aston",
#     SumScore = 3,
#     FinalTimeResult = "2-1",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T02:00:00"),
#     HomeImg = "Chelsea.png",
#     AwayImg = "Aston.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996153,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Brighton",
#     AwayTeam = "United",
#     SumScore = 2,
#     FinalTimeResult = "2-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T01:57:00"),
#     HomeImg = "Brighton.png",
#     AwayImg = "United.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996148,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "City",
#     AwayTeam = "Brentford",
#     SumScore = 4,
#     FinalTimeResult = "1-3",
#     HalfTimeResult = "1-1",
#     GameDate = DateTime.Parse("2023-12-27T01:54:00"),
#     HomeImg = "City.png",
#     AwayImg = "Brentford.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996144,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Aston",
#     AwayTeam = "Wolverhampton",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T01:51:00"),
#     HomeImg = "Aston.png",
#     AwayImg = "Wolverhampton.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996140,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Leeds",
#     AwayTeam = "West Ham",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T01:48:00"),
#     HomeImg = "Leeds.png",
#     AwayImg = "West Ham.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996136,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Wolverhampton",
#     AwayTeam = "Liverpool",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T01:45:00"),
#     HomeImg = "Wolverhampton.png",
#     AwayImg = "Liverpool.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996132,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Tottenham",
#     AwayTeam = "Palace",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T01:42:00"),
#     HomeImg = "Tottenham.png",
#     AwayImg = "Palace.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996128,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Leeds",
#     AwayTeam = "Brentford",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T01:39:00"),
#     HomeImg = "Leeds.png",
#     AwayImg = "Brentford.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996123,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "West Ham",
#     AwayTeam = "Leicester",
#     SumScore = 4,
#     FinalTimeResult = "2-2",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T01:36:00"),
#     HomeImg = "West Ham.png",
#     AwayImg = "Leicester.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996118,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Brighton",
#     AwayTeam = "Southampton",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T01:33:00"),
#     HomeImg = "Brighton.png",
#     AwayImg = "Southampton.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996114,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "City",
#     AwayTeam = "Islington",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T01:30:00"),
#     HomeImg = "City.png",
#     AwayImg = "islingtonreds.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996109,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Aston",
#     AwayTeam = "Brighton",
#     SumScore = 4,
#     FinalTimeResult = "3-1",
#     HalfTimeResult = "1-1",
#     GameDate = DateTime.Parse("2023-12-27T01:27:00"),
#     HomeImg = "Aston.png",
#     AwayImg = "Brighton.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996105,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "United",
#     AwayTeam = "Leicester",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T01:24:00"),
#     HomeImg = "United.png",
#     AwayImg = "Leicester.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996101,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Brentford",
#     AwayTeam = "Southampton",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T01:21:00"),
#     HomeImg = "Brentford.png",
#     AwayImg = "Southampton.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996097,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Palace",
#     AwayTeam = "Newcastle",
#     SumScore = 4,
#     FinalTimeResult = "3-1",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T01:18:00"),
#     HomeImg = "Palace.png",
#     AwayImg = "Newcastle.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996093,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Norwich",
#     AwayTeam = "Watford",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T01:15:00"),
#     HomeImg = "Norwich.png",
#     AwayImg = "watford.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996089,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "City",
#     AwayTeam = "Tottenham",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T01:12:00"),
#     HomeImg = "City.png",
#     AwayImg = "Tottenham.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996085,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Liverpool",
#     AwayTeam = "Wolverhampton",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T01:09:00"),
#     HomeImg = "Liverpool.png",
#     AwayImg = "Wolverhampton.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996081,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Burnley",
#     AwayTeam = "Leicester",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T01:06:00"),
#     HomeImg = "Burnley.png",
#     AwayImg = "Leicester.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996077,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "West Ham",
#     AwayTeam = "Everton",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T01:03:00"),
#     HomeImg = "West Ham.png",
#     AwayImg = "Everton.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996073,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Burnley",
#     AwayTeam = "Norwich",
#     SumScore = 1,
#     FinalTimeResult = "0-1",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T01:00:00"),
#     HomeImg = "Burnley.png",
#     AwayImg = "Norwich.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996068,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Brighton",
#     AwayTeam = "West Ham",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T00:57:00"),
#     HomeImg = "Brighton.png",
#     AwayImg = "West Ham.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996064,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Brentford",
#     AwayTeam = "Tottenham",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T00:54:00"),
#     HomeImg = "Brentford.png",
#     AwayImg = "Tottenham.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996059,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Watford",
#     AwayTeam = "Everton",
#     SumScore = 3,
#     FinalTimeResult = "0-3",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T00:51:00"),
#     HomeImg = "watford.png",
#     AwayImg = "Everton.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996055,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Aston",
#     AwayTeam = "Tottenham",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "1-1",
#     GameDate = DateTime.Parse("2023-12-27T00:48:00"),
#     HomeImg = "Aston.png",
#     AwayImg = "Tottenham.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996051,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "United",
#     AwayTeam = "West Ham",
#     SumScore = 2,
#     FinalTimeResult = "2-0",
#     HalfTimeResult = "2-0",
#     GameDate = DateTime.Parse("2023-12-27T00:45:00"),
#     HomeImg = "United.png",
#     AwayImg = "West Ham.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996046,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Leicester",
#     AwayTeam = "Everton",
#     SumScore = 7,
#     FinalTimeResult = "2-5+",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T00:42:00"),
#     HomeImg = "Leicester.png",
#     AwayImg = "Everton.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996040,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Burnley",
#     AwayTeam = "United",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "1-1",
#     GameDate = DateTime.Parse("2023-12-27T00:39:00"),
#     HomeImg = "Burnley.png",
#     AwayImg = "United.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996036,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Wolverhampton",
#     AwayTeam = "Leicester",
#     SumScore = 2,
#     FinalTimeResult = "1-1",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T00:36:00"),
#     HomeImg = "Wolverhampton.png",
#     AwayImg = "Leicester.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996032,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Palace",
#     AwayTeam = "West Ham",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T00:33:00"),
#     HomeImg = "Palace.png",
#     AwayImg = "West Ham.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996028,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Brighton",
#     AwayTeam = "City",
#     SumScore = 4,
#     FinalTimeResult = "0-4",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T00:30:00"),
#     HomeImg = "Brighton.png",
#     AwayImg = "City.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996024,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Burnley",
#     AwayTeam = "Wolverhampton",
#     SumScore = 4,
#     FinalTimeResult = "1-3",
#     HalfTimeResult = "0-1",
#     GameDate = DateTime.Parse("2023-12-27T00:27:00"),
#     HomeImg = "Burnley.png",
#     AwayImg = "Wolverhampton.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996020,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Palace",
#     AwayTeam = "United",
#     SumScore = 4,
#     FinalTimeResult = "3-1",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T00:24:00"),
#     HomeImg = "Palace.png",
#     AwayImg = "United.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996016,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Aston",
#     AwayTeam = "Everton",
#     SumScore = 6,
#     FinalTimeResult = "4-2",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T00:21:00"),
#     HomeImg = "Aston.png",
#     AwayImg = "Everton.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996012,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Islington",
#     AwayTeam = "Brighton",
#     SumScore = 0,
#     FinalTimeResult = "0-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T00:18:00"),
#     HomeImg = "islingtonreds.png",
#     AwayImg = "Brighton.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996007,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "West Ham",
#     AwayTeam = "Newcastle",
#     SumScore = 3,
#     FinalTimeResult = "2-1",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T00:15:00"),
#     HomeImg = "West Ham.png",
#     AwayImg = "Newcastle.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2996003,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Brentford",
#     AwayTeam = "Islington",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T00:12:00"),
#     HomeImg = "Brentford.png",
#     AwayImg = "islingtonreds.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2995999,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "West Ham",
#     AwayTeam = "Norwich",
#     SumScore = 3,
#     FinalTimeResult = "2-1",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T00:09:00"),
#     HomeImg = "West Ham.png",
#     AwayImg = "Norwich.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2995993,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Newcastle",
#     AwayTeam = "Wolverhampton",
#     SumScore = 7,
#     FinalTimeResult = "2-5+",
#     HalfTimeResult = "OUTROS",
#     GameDate = DateTime.Parse("2023-12-27T00:06:00"),
#     HomeImg = "Newcastle.png",
#     AwayImg = "Wolverhampton.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2995989,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Watford",
#     AwayTeam = "Aston",
#     SumScore = 3,
#     FinalTimeResult = "2-1",
#     HalfTimeResult = "1-0",
#     GameDate = DateTime.Parse("2023-12-27T00:03:00"),
#     HomeImg = "watford.png",
#     AwayImg = "Aston.png"
# },
# new FutebolVirtualGames
# {
#     Id = 2995985,
#     LeagueId = 20120653,
#     League = "Premiership",
#     HomeTeam = "Tottenham",
#     AwayTeam = "Burnley",
#     SumScore = 1,
#     FinalTimeResult = "1-0",
#     HalfTimeResult = "0-0",
#     GameDate = DateTime.Parse("2023-12-27T00:00:00"),
#     HomeImg = "Tottenham.png",
#     AwayImg = "Burnley.png"
# },
